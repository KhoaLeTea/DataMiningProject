# %%
from collections import OrderedDict
import json
import csv
import numpy as np
import matplotlib as plt
import pandas as pd
from scipy.sparse import linalg
from scipy import dot
import logging, gensim, bz2
from gensim import corpora
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def get_business_categories(business_file):
    
    all_categories = {'NONE': 0}
    businesses = OrderedDict()

    with open(business_file) as all_business_data:

        for single_business_data in all_business_data:

            business = json.loads(single_business_data)
            b_id = business.pop('business_id')
            
            atts_to_remove = [
                'attributes',
                'hours',
                'name',
                'hours',
                'neighborhood',
                'address',
                'state',
                'is_open',
                'type'
            ]
            
            keys = list(business.keys())
            for key in keys:
                if key in atts_to_remove:
                    del business[key]
            
            categories = business['categories']
            businesses[b_id] = business

            if categories:
                for category in categories:
                    if category not in all_categories.keys():
                        all_categories[category] = 1
                    else:
                        all_categories[category] += 1
            else:
                business['categories'] = ['NONE']
                all_categories['NONE'] += 1

    all_categories = OrderedDict([ (tup[0], [i, tup[1]]) for i, tup in enumerate(sorted(all_categories.items(), key=lambda t: t[1], reverse=True))])
    
    return businesses, all_categories

def build_business_cat_vectors(biz_list, list_of_catlists, cat_idxs):
    cat_vectors = []
    vec_length = len(cat_idxs.keys())
    for cat_list in list_of_catlists:
        cat_vector = [0] * vec_length
        for cat in cat_list:
            idx = cat_idxs[cat][0]
            cat_vector[idx] = 1
        cat_vectors.append(tuple(cat_vector))
            
    # returns a {biz_id : (cat_vector)} dictionary
    return OrderedDict(zip(biz_list, cat_vectors))

business_json = '../yelp_data/yelp_academic_dataset_business.json'

bizs, cats = get_business_categories(business_json)

# %%
cat_frame = {}
count=0
for cat, data in cats.items():
    cat_frame[cat] = [data[1]]
    if count>10:
        break
    count += 1 
    
# print(sorted(cat_frame, key=lambda x: {y:x}))
cdf = pd.DataFrame(cat_frame)
cdf.head()
# Out:
#    Active Life  Automotive  Bars  Beauty & Spas  Event Planning & Services  \
# 0         6722        8554  9087          13711                       7224
#
#     Food  Health & Medical  Home Services  Local Services  Nightlife  \
# 0  21189             10476          11241            8133      10524
#
#    Restaurants  Shopping
# 0        48485     22466

# %%
bizcattuples = [(b_id, biz['categories']) for b_id, biz in bizs.items()]
bizidlist, cat_lists = zip(*bizcattuples)
biz_cat_vectors = build_business_cat_vectors(bizidlist, cat_lists, cats)

# %%
dictionary = corpora.Dictionary(cat_lists)
# Out:
# 2017-05-01 15:37:51,009 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2017-05-01 15:37:51,231 : INFO : adding document #10000 to Dictionary(887 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:51,417 : INFO : adding document #20000 to Dictionary(991 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:51,594 : INFO : adding document #30000 to Dictionary(1031 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:51,773 : INFO : adding document #40000 to Dictionary(1078 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:51,959 : INFO : adding document #50000 to Dictionary(1111 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:52,142 : INFO : adding document #60000 to Dictionary(1131 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:52,327 : INFO : adding document #70000 to Dictionary(1145 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:52,508 : INFO : adding document #80000 to Dictionary(1157 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:52,705 : INFO : adding document #90000 to Dictionary(1165 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:52,886 : INFO : adding document #100000 to Dictionary(1173 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:53,070 : INFO : adding document #110000 to Dictionary(1180 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:53,250 : INFO : adding document #120000 to Dictionary(1183 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:53,432 : INFO : adding document #130000 to Dictionary(1185 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:53,618 : INFO : adding document #140000 to Dictionary(1191 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...)
# 2017-05-01 15:37:53,694 : INFO : built Dictionary(1192 unique tokens: ['Desserts', 'Flight Instruction', 'Internet Service Providers', 'Spanish', 'Pet Adoption']...) from 144072 documents (total 527929 corpus positions)

# %%
gensim_corpus = [dictionary.doc2bow(text) for text in cat_lists]

# %%
mm = gensim.corpora.MmCorpus('../corpus.mm')
# Out:
# 2017-05-01 15:38:01,280 : INFO : loaded corpus index from ../corpus.mm.index
# 2017-05-01 15:38:01,281 : INFO : initializing corpus reader from ../corpus.mm
# 2017-05-01 15:38:01,283 : INFO : accepted corpus with 144072 documents, 1192 features, 527929 non-zero entries

# %%
lsi = gensim.models.lsimodel.LsiModel(corpus=mm, id2word=dictionary, num_topics=50, onepass=False)
# Out:
# 2017-05-01 15:38:02,144 : INFO : using serial LSI version on this node
# 2017-05-01 15:38:02,146 : INFO : updating model with new documents
# 2017-05-01 15:38:02,147 : INFO : using 100 extra samples and 2 power iterations
# 2017-05-01 15:38:02,148 : INFO : 1st phase: constructing (1192, 150) action matrix
# 2017-05-01 15:38:02,740 : INFO : PROGRESS: at document #0
# 2017-05-01 15:38:03,295 : INFO : PROGRESS: at document #20000
# 2017-05-01 15:38:03,923 : INFO : PROGRESS: at document #40000
# 2017-05-01 15:38:04,455 : INFO : PROGRESS: at document #60000
# 2017-05-01 15:38:05,043 : INFO : PROGRESS: at document #80000
# 2017-05-01 15:38:05,581 : INFO : PROGRESS: at document #100000
# 2017-05-01 15:38:06,119 : INFO : PROGRESS: at document #120000
# 2017-05-01 15:38:06,397 : INFO : PROGRESS: at document #140000
# 2017-05-01 15:38:06,462 : INFO : running power iteration #1
# 2017-05-01 15:38:06,801 : INFO : PROGRESS: at document #0/144072
# 2017-05-01 15:38:07,217 : INFO : PROGRESS: at document #20000/144072
# 2017-05-01 15:38:07,867 : INFO : PROGRESS: at document #40000/144072
# 2017-05-01 15:38:08,287 : INFO : PROGRESS: at document #60000/144072
# 2017-05-01 15:38:08,707 : INFO : PROGRESS: at document #80000/144072
# 2017-05-01 15:38:09,127 : INFO : PROGRESS: at document #100000/144072
# 2017-05-01 15:38:09,544 : INFO : PROGRESS: at document #120000/144072
# 2017-05-01 15:38:09,693 : INFO : PROGRESS: at document #140000/144072
# 2017-05-01 15:38:09,730 : INFO : running power iteration #2
# 2017-05-01 15:38:10,066 : INFO : PROGRESS: at document #0/144072
# 2017-05-01 15:38:10,480 : INFO : PROGRESS: at document #20000/144072
# 2017-05-01 15:38:10,891 : INFO : PROGRESS: at document #40000/144072
# 2017-05-01 15:38:11,534 : INFO : PROGRESS: at document #60000/144072
# 2017-05-01 15:38:11,950 : INFO : PROGRESS: at document #80000/144072
# 2017-05-01 15:38:12,355 : INFO : PROGRESS: at document #100000/144072
# 2017-05-01 15:38:12,761 : INFO : PROGRESS: at document #120000/144072
# 2017-05-01 15:38:12,915 : INFO : PROGRESS: at document #140000/144072
# 2017-05-01 15:38:12,953 : INFO : 2nd phase: constructing (150, 150) covariance matrix
# 2017-05-01 15:38:13,277 : INFO : PROGRESS: at document #0/144072
# 2017-05-01 15:38:13,695 : INFO : PROGRESS: at document #20000/144072
# 2017-05-01 15:38:14,127 : INFO : PROGRESS: at document #40000/144072
# 2017-05-01 15:38:14,546 : INFO : PROGRESS: at document #60000/144072
# 2017-05-01 15:38:14,966 : INFO : PROGRESS: at document #80000/144072
# 2017-05-01 15:38:15,631 : INFO : PROGRESS: at document #100000/144072
# 2017-05-01 15:38:16,050 : INFO : PROGRESS: at document #120000/144072
# 2017-05-01 15:38:16,211 : INFO : PROGRESS: at document #140000/144072
# 2017-05-01 15:38:16,233 : INFO : running dense decomposition on (150, 150) covariance matrix
# 2017-05-01 15:38:16,241 : INFO : computing the final decomposition
# 2017-05-01 15:38:16,243 : INFO : keeping 50 factors (discarding 20.633% of energy spectrum)

# %%
def assign_topics(biz_dict, lsi_model):
    for biz_id, biz in biz_dict.items():
        vector = dictionary.doc2bow( biz['categories'] )
        topic = max( lsi_model[vector], key=lambda tup: tup[1] )
        biz['topic'] = topic[0]
        biz.pop('categories')

assign_topics(bizs, lsi)

# %%
biz_out = '../yelp_data/business_compressed.csv'

with open(biz_out, 'w') as csvfile:
    names = ['business_id', 'city', 'longitude', 'latitude', 'postal_code', 'review_count', 'stars', 'topic']
    writer = csv.DictWriter(csvfile, fieldnames=names)
    
    writer.writeheader()
    
    for biz_id, biz in bizs.items():
        biz['business_id'] = biz_id
        writer.writerow(biz)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-0ab6be32755c> in <module>()
#       9     for biz_id, biz in bizs.items():
#      10         biz['business_id'] = biz_id
# ---> 11         writer.writerow(biz)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/csv.py in writerow(self, rowdict)
#     151
#     152     def writerow(self, rowdict):
# --> 153         return self.writer.writerow(self._dict_to_list(rowdict))
#     154
#     155     def writerows(self, rowdicts):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/csv.py in _dict_to_list(self, rowdict)
#     147             if wrong_fields:
#     148                 raise ValueError("dict contains fields not in fieldnames: "
# --> 149                                  + ", ".join([repr(x) for x in wrong_fields]))
#     150         return (rowdict.get(key, self.restval) for key in self.fieldnames)
#     151
#
# ValueError: dict contains fields not in fieldnames: 'categories'

# %%
_kwargs = dict(formatted=0, num_words=20)
# tups = [tups for tups in lsi.show_topics(**_kwargs)]
topic_words = [[t[0] for t in tups[1]] for tups in lsi.show_topics(**_kwargs)]

# %%
topic_words[1]
# Out:
# ['Tobacco Shops',
#  'Leather Goods',
#  'Food',
#  'Permanent Makeup',
#  'Home & Garden',
#  'Professional Services',
#  'Self Storage',
#  'Italian',
#  "Women's Clothing",
#  'General Dentistry',
#  'Cosmetics & Beauty Supply',
#  'Accessories',
#  'Department Stores',
#  'Massage',
#  'Shoe Stores',
#  'Flowers & Gifts',
#  'Sporting Goods',
#  'Event Planning & Services',
#  'Mattresses',
#  'Office Equipment']

# %%
framed_words = []
for i in range(0,20):
        row = {}
        for j in range(0, len(topic_words)):
            row[j+1] = topic_words[j][i]
        framed_words.append(row)

# %%
frame = pd.DataFrame.from_records(framed_words)

# %%
frame.head(10)
# Out:
#                        1                      2                          3   \
# 0                 Italian          Tobacco Shops                       Food
# 1                    Food          Leather Goods               Coffee & Tea
# 2               Nightlife                   Food              Tobacco Shops
# 3                    Pubs       Permanent Makeup                    Italian
# 4  American (Traditional)          Home & Garden                  Nightlife
# 5      Breakfast & Brunch  Professional Services                       Pubs
# 6           Chicken Wings           Self Storage                    Grocery
# 7               Fast Food                Italian                   Bakeries
# 8                   Pizza       Women's Clothing  Event Planning & Services
# 9          Canadian (New)      General Dentistry                   Desserts
#
#                   4                       5                      6   \
# 0   Permanent Makeup               Nightlife  Professional Services
# 1            Massage                    Pubs            Real Estate
# 2  General Dentistry                 Italian           Self Storage
# 3        Nail Salons                    Food     Wheel & Rim Repair
# 4      Tobacco Shops          American (New)          Tobacco Shops
# 5             Waxing             Sports Bars   Real Estate Services
# 6          Skin Care               Fast Food          Leather Goods
# 7           Day Spas    Arts & Entertainment            Contractors
# 8       Hair Removal  American (Traditional)            Auto Repair
# 9            Doctors             Dance Clubs          Home Services
#
#                       7                       8                      9   \
# 0      General Dentistry      Wheel & Rim Repair               Caterers
# 1                Doctors             Auto Repair                 Hotels
# 2       Permanent Makeup   Professional Services            Active Life
# 3               Dentists     Oil Change Stations        Hotels & Travel
# 4       Health & Medical                   Tires  Fitness & Instruction
# 5                Massage              Automotive   Arts & Entertainment
# 6            Active Life        Used Car Dealers  Venues & Event Spaces
# 7          Periodontists             Real Estate                   Gyms
# 8            Nail Salons              Body Shops      General Dentistry
# 9  Fitness & Instruction  Gas & Service Stations         Specialty Food
#
#                       10         ...                             41  \
# 0            Active Life         ...                    Active Life
# 1  Fitness & Instruction         ...          Fitness & Instruction
# 2               Caterers         ...                           Gyms
# 3                 Hotels         ...                 Life Insurance
# 4                   Gyms         ...                 Sporting Goods
# 5        Hotels & Travel         ...                       Trainers
# 6               Trainers         ...                Flowers & Gifts
# 7      General Dentistry         ...                          Parks
# 8                   Yoga         ...          Banks & Credit Unions
# 9           Self Storage         ...                          Bikes
#
#                           42                         43  \
# 0                Auto Repair  Ice Cream & Frozen Yogurt
# 1         Wheel & Rim Repair                   Bakeries
# 2        Oil Change Stations                Auto Repair
# 3  Event Planning & Services         Wheel & Rim Repair
# 4     Gas & Service Stations        Oil Change Stations
# 5                   Bakeries                      Tires
# 6                      Tires                    Mexican
# 7         Convenience Stores             Canadian (New)
# 8                    Mexican                 Sushi Bars
# 9  Ice Cream & Frozen Yogurt     Gas & Service Stations
#
#                           44                         45                46  \
# 0            Flowers & Gifts                      Cafes   Flowers & Gifts
# 1  Cosmetics & Beauty Supply  Ice Cream & Frozen Yogurt           Doctors
# 2               Hair Removal              Mediterranean          Florists
# 3                   Day Spas                   Bakeries       Active Life
# 4                   Florists               Coffee & Tea     Fabric Stores
# 5                    Massage                    Seafood       Nail Salons
# 6  Ice Cream & Frozen Yogurt                    Chinese  Women's Clothing
# 7              Fabric Stores                    Mexican    Sporting Goods
# 8                Nail Salons                 Sushi Bars           Massage
# 9                    Doctors                   Lebanese          Day Spas
#
#                  47                         48                 49  \
# 0    Sporting Goods                    Seafood            Doctors
# 1  Women's Clothing                Steakhouses           Day Spas
# 2       Sports Wear             American (New)        Electronics
# 3       Electronics                   Desserts          Computers
# 4     Mobile Phones              Mediterranean       Optometrists
# 5       Active Life                Dance Clubs      Mobile Phones
# 6         Computers                      Greek            Seafood
# 7             Bikes                   Lebanese  General Dentistry
# 8       Accessories                    Doctors            Jewelry
# 9             Parks  Event Planning & Services             Waxing
#
#                    50
# 0            Day Spas
# 1            Desserts
# 2   Department Stores
# 3      American (New)
# 4             Doctors
# 5       Mediterranean
# 6             Seafood
# 7   Men's Hair Salons
# 8    Women's Clothing
# 9  Convenience Stores
#
# [10 rows x 50 columns]
