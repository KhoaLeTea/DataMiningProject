# %%
from collections import OrderedDict
import json
import csv
import numpy as np
import matplotlib as plt
import pandas as pd
from scipy.sparse import linalg
from scipy import dot
import logging, gensim, bz2
from gensim import corpora
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def get_business_categories(business_file):
    
    all_categories = {'NONE': 0}
    businesses = OrderedDict()

    with open(business_file) as all_business_data:

        for single_business_data in all_business_data:

            business = json.loads(single_business_data)
            b_id = business.pop('business_id')
            
            atts_to_remove = [
                'attributes',
                'hours',
                'name',
                'hours',
                'neighborhood',
                'address',
                'state',
                'is_open',
                'type'
            ]
            
            keys = list(business.keys())
            for key in keys:
                if key in atts_to_remove:
                    del business[key]
            
            categories = business['categories']
            businesses[b_id] = business

            if categories:
                for category in categories:
                    if category not in all_categories.keys():
                        all_categories[category] = 1
                    else:
                        all_categories[category] += 1
            else:
                business['categories'] = ['NONE']
                all_categories['NONE'] += 1

    all_categories = OrderedDict([ (tup[0], [i, tup[1]]) for i, tup in enumerate(sorted(all_categories.items(), key=lambda t: t[1], reverse=True))])
    
    return businesses, all_categories

def build_business_cat_vectors(biz_list, list_of_catlists, cat_idxs):
    cat_vectors = []
    vec_length = len(cat_idxs.keys())
    for cat_list in list_of_catlists:
        cat_vector = [0] * vec_length
        for cat in cat_list:
            idx = cat_idxs[cat][0]
            cat_vector[idx] = 1
        cat_vectors.append(tuple(cat_vector))
            
    # returns a {biz_id : (cat_vector)} dictionary
    return OrderedDict(zip(biz_list, cat_vectors))

business_json = '../yelp_data/yelp_academic_dataset_business.json'

bizs, cats = get_business_categories(business_json)

# %%
cat_frame = {}
count=0
for cat, data in cats.items():
    cat_frame[cat] = [data[1]]
    if count>10:
        break
    count += 1 
    
print(sorted(cat_frame, key=lambda x: {y:x}))
cdf = pd.DataFrame(cat_frame)
cdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2e4c5a868e23> in <module>()
#       7     count += 1
#       8
# ----> 9 print(sorted(cat_frame, key=lambda x: {y:x}))
#      10 cdf = pd.DataFrame(cat_frame)
#      11 cdf.head()
#
# <ipython-input-3-2e4c5a868e23> in <lambda>(x)
#       7     count += 1
#       8
# ----> 9 print(sorted(cat_frame, key=lambda x: {y:x}))
#      10 cdf = pd.DataFrame(cat_frame)
#      11 cdf.head()
#
# NameError: name 'y' is not defined

# %%
bizcattuples = [(b_id, biz['categories']) for b_id, biz in bizs.items()]
bizidlist, cat_lists = zip(*bizcattuples)
biz_cat_vectors = build_business_cat_vectors(bizidlist, cat_lists, cats)

# %%
dictionary = corpora.Dictionary(cat_lists)
# Out:
# 2017-05-01 14:49:06,226 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2017-05-01 14:49:06,452 : INFO : adding document #10000 to Dictionary(887 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Nail Salons', 'Amateur Sports Teams', 'Breakfast & Brunch']...)
# 2017-05-01 14:49:06,643 : INFO : adding document #20000 to Dictionary(991 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Nail Salons', 'Amateur Sports Teams', 'Breakfast & Brunch']...)
# 2017-05-01 14:49:06,830 : INFO : adding document #30000 to Dictionary(1031 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Nail Salons', 'Amateur Sports Teams', 'Breakfast & Brunch']...)
# 2017-05-01 14:49:07,019 : INFO : adding document #40000 to Dictionary(1078 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Nail Salons', 'Amateur Sports Teams', 'Breakfast & Brunch']...)
# 2017-05-01 14:49:07,204 : INFO : adding document #50000 to Dictionary(1111 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:07,389 : INFO : adding document #60000 to Dictionary(1131 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:07,571 : INFO : adding document #70000 to Dictionary(1145 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:07,750 : INFO : adding document #80000 to Dictionary(1157 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:07,938 : INFO : adding document #90000 to Dictionary(1165 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:08,120 : INFO : adding document #100000 to Dictionary(1173 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:08,314 : INFO : adding document #110000 to Dictionary(1180 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:08,510 : INFO : adding document #120000 to Dictionary(1183 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:08,705 : INFO : adding document #130000 to Dictionary(1185 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:08,901 : INFO : adding document #140000 to Dictionary(1191 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...)
# 2017-05-01 14:49:08,988 : INFO : built Dictionary(1192 unique tokens: ['Auto Loan Providers', 'Recycling Center', 'Preventive Medicine', 'Nail Salons', 'Amateur Sports Teams']...) from 144072 documents (total 527929 corpus positions)

# %%
gensim_corpus = [dictionary.doc2bow(text) for text in cat_lists]

# %%
mm = gensim.corpora.MmCorpus('../corpus.mm')
# Out:
# 2017-05-01 14:49:28,222 : INFO : loaded corpus index from ../corpus.mm.index
# 2017-05-01 14:49:28,223 : INFO : initializing corpus reader from ../corpus.mm
# 2017-05-01 14:49:28,224 : INFO : accepted corpus with 144072 documents, 1192 features, 527929 non-zero entries

# %%
lsi = gensim.models.lsimodel.LsiModel(corpus=mm, id2word=dictionary, num_topics=50, onepass=False)
# Out:
# 2017-05-01 14:49:33,069 : INFO : using serial LSI version on this node
# 2017-05-01 14:49:33,070 : INFO : updating model with new documents
# 2017-05-01 14:49:33,071 : INFO : using 100 extra samples and 2 power iterations
# 2017-05-01 14:49:33,072 : INFO : 1st phase: constructing (1192, 150) action matrix
# 2017-05-01 14:49:33,697 : INFO : PROGRESS: at document #0
# 2017-05-01 14:49:34,284 : INFO : PROGRESS: at document #20000
# 2017-05-01 14:49:34,881 : INFO : PROGRESS: at document #40000
# 2017-05-01 14:49:35,523 : INFO : PROGRESS: at document #60000
# 2017-05-01 14:49:36,111 : INFO : PROGRESS: at document #80000
# 2017-05-01 14:49:36,709 : INFO : PROGRESS: at document #100000
# 2017-05-01 14:49:37,273 : INFO : PROGRESS: at document #120000
# 2017-05-01 14:49:37,613 : INFO : PROGRESS: at document #140000
# 2017-05-01 14:49:37,693 : INFO : running power iteration #1
# 2017-05-01 14:49:38,041 : INFO : PROGRESS: at document #0/144072
# 2017-05-01 14:49:38,471 : INFO : PROGRESS: at document #20000/144072
# 2017-05-01 14:49:39,156 : INFO : PROGRESS: at document #40000/144072
# 2017-05-01 14:49:39,576 : INFO : PROGRESS: at document #60000/144072
# 2017-05-01 14:49:40,014 : INFO : PROGRESS: at document #80000/144072
# 2017-05-01 14:49:40,440 : INFO : PROGRESS: at document #100000/144072
# 2017-05-01 14:49:40,860 : INFO : PROGRESS: at document #120000/144072
# 2017-05-01 14:49:41,021 : INFO : PROGRESS: at document #140000/144072
# 2017-05-01 14:49:41,056 : INFO : running power iteration #2
# 2017-05-01 14:49:41,402 : INFO : PROGRESS: at document #0/144072
# 2017-05-01 14:49:41,841 : INFO : PROGRESS: at document #20000/144072
# 2017-05-01 14:49:42,275 : INFO : PROGRESS: at document #40000/144072
# 2017-05-01 14:49:42,948 : INFO : PROGRESS: at document #60000/144072
# 2017-05-01 14:49:43,375 : INFO : PROGRESS: at document #80000/144072
# 2017-05-01 14:49:43,799 : INFO : PROGRESS: at document #100000/144072
# 2017-05-01 14:49:44,214 : INFO : PROGRESS: at document #120000/144072
# 2017-05-01 14:49:44,367 : INFO : PROGRESS: at document #140000/144072
# 2017-05-01 14:49:44,408 : INFO : 2nd phase: constructing (150, 150) covariance matrix
# 2017-05-01 14:49:44,745 : INFO : PROGRESS: at document #0/144072
# 2017-05-01 14:49:45,183 : INFO : PROGRESS: at document #20000/144072
# 2017-05-01 14:49:45,625 : INFO : PROGRESS: at document #40000/144072
# 2017-05-01 14:49:46,064 : INFO : PROGRESS: at document #60000/144072
# 2017-05-01 14:49:46,491 : INFO : PROGRESS: at document #80000/144072
# 2017-05-01 14:49:47,208 : INFO : PROGRESS: at document #100000/144072
# 2017-05-01 14:49:47,704 : INFO : PROGRESS: at document #120000/144072
# 2017-05-01 14:49:47,905 : INFO : PROGRESS: at document #140000/144072
# 2017-05-01 14:49:47,931 : INFO : running dense decomposition on (150, 150) covariance matrix
# 2017-05-01 14:49:47,941 : INFO : computing the final decomposition
# 2017-05-01 14:49:47,942 : INFO : keeping 50 factors (discarding 20.596% of energy spectrum)

# %%
def assign_topics(biz_dict, lsi_model):
    for biz_id, biz in biz_dict.items():
        vector = dictionary.doc2bow( biz['categories'] )
        topic = max( lsi_model[vector], key=lambda tup: tup[1] )
        biz['topic'] = topic[0]
        biz.pop('categories')

assign_topics(bizs, lsi)

# %%
biz_out = 'yelp_data/business_compressed.csv'

with open(biz_out, 'w') as csvfile:
    names = ['business_id', 'city', 'longitude', 'latitude', 'postal_code', 'review_count', 'stars', 'topic']
    writer = csv.DictWriter(csvfile, fieldnames=names)
    
    writer.writeheader()
    
    for biz_id, biz in bizs.items():
        biz['business_id'] = biz_id
        writer.writerow(biz)

# %%
_kwargs = dict(formatted=0, num_words=20)
# tups = [tups for tups in lsi.show_topics(**_kwargs)]
topic_words = [[t[0] for t in tups[1]] for tups in lsi.show_topics(**_kwargs)]

# %%
topic_words[1]
# Out:
# ['Tobacco Shops',
#  'Leather Goods',
#  'Party & Event Planning',
#  'Hair Extensions',
#  'Cabinetry',
#  'Professional Services',
#  'Self Storage',
#  'Chicken Wings',
#  'Gift Shops',
#  'Health & Medical',
#  'Cosmetics & Beauty Supply',
#  'Fashion',
#  'Department Stores',
#  'Hair Removal',
#  'Shoe Stores',
#  'Florists',
#  'Sporting Goods',
#  'Specialty Food',
#  'Home Decor',
#  'Furniture Stores']

# %%
framed_words = []
for i in range(0,20):
        row = {}
        for j in range(0, len(topic_words)):
            row[j+1] = topic_words[j][i]
        framed_words.append(row)

# %%
frame = pd.DataFrame.from_records(framed_words)

# %%
frame.head(10)
# Out:
#                        1                       2                          3   \
# 0           Chicken Wings           Tobacco Shops     Party & Event Planning
# 1  Party & Event Planning           Leather Goods                   Desserts
# 2               Nightlife  Party & Event Planning              Tobacco Shops
# 3          American (New)         Hair Extensions              Chicken Wings
# 4  American (Traditional)               Cabinetry                  Nightlife
# 5              Sandwiches   Professional Services             American (New)
# 6                 Italian            Self Storage  Event Planning & Services
# 7                 Tex-Mex           Chicken Wings                   Bakeries
# 8                   Pizza              Gift Shops             Specialty Food
# 9          Canadian (New)        Health & Medical               Coffee & Tea
#
#                  4                       5                      6   \
# 0   Hair Extensions               Nightlife  Professional Services
# 1      Hair Removal          American (New)             Apartments
# 2  Health & Medical           Chicken Wings           Self Storage
# 3       Nail Salons  Party & Event Planning     Wheel & Rim Repair
# 4     Tobacco Shops                    Bars          Tobacco Shops
# 5  Permanent Makeup             Sports Bars            Real Estate
# 6         Skin Care                 Tex-Mex          Leather Goods
# 7      Medical Spas         Performing Arts     Telecommunications
# 8            Waxing  American (Traditional)    Oil Change Stations
# 9   Sports Medicine             Dance Clubs          Home Services
#
#                       7                       8                      9   \
# 0       Health & Medical      Wheel & Rim Repair               Caterers
# 1        Sports Medicine     Oil Change Stations        Hotels & Travel
# 2        Hair Extensions   Professional Services           Sports Clubs
# 3               Dentists             Auto Repair                 Hotels
# 4      General Dentistry   Auto Parts & Supplies  Fitness & Instruction
# 5           Hair Removal              Automotive        Performing Arts
# 6           Sports Clubs              Car Buyers  Venues & Event Spaces
# 7      Cosmetic Dentists              Apartments                   Gyms
# 8            Nail Salons              Body Shops       Health & Medical
# 9  Fitness & Instruction  Gas & Service Stations                Grocery
#
#                       10         ...                             41  \
# 0           Sports Clubs         ...                   Sports Clubs
# 1  Fitness & Instruction         ...          Fitness & Instruction
# 2               Caterers         ...                           Gyms
# 3        Hotels & Travel         ...                 Life Insurance
# 4                   Gyms         ...                 Sporting Goods
# 5                 Hotels         ...                       Trainers
# 6               Trainers         ...                       Florists
# 7       Health & Medical         ...                          Parks
# 8                   Yoga         ...          Banks & Credit Unions
# 9           Self Storage         ...                          Bikes
#
#                           42                         43  \
# 0        Oil Change Stations  Ice Cream & Frozen Yogurt
# 1         Wheel & Rim Repair                   Bakeries
# 2                Auto Repair        Oil Change Stations
# 3             Specialty Food         Wheel & Rim Repair
# 4                   Bakeries                Auto Repair
# 5     Gas & Service Stations      Auto Parts & Supplies
# 6      Auto Parts & Supplies                  Fast Food
# 7         Convenience Stores             Canadian (New)
# 8                  Fast Food     Gas & Service Stations
# 9  Ice Cream & Frozen Yogurt                 Sushi Bars
#
#                           44                         45               46  \
# 0                   Florists                      Cafes         Florists
# 1  Cosmetics & Beauty Supply  Ice Cream & Frozen Yogurt  Sports Medicine
# 2                     Waxing                    Turkish  Flowers & Gifts
# 3               Medical Spas                   Bakeries     Sports Clubs
# 4            Flowers & Gifts                    Seafood       Gift Shops
# 5  Ice Cream & Frozen Yogurt                   Desserts      Nail Salons
# 6               Hair Removal                    Chinese    Fabric Stores
# 7              Fabric Stores                  Fast Food   Sporting Goods
# 8                Nail Salons                 Sushi Bars        Computers
# 9            Sports Medicine             Middle Eastern     Medical Spas
#
#                47               48                49                  50
# 0  Sporting Goods          Seafood   Sports Medicine        Medical Spas
# 1      Gift Shops      Steakhouses      Medical Spas        Coffee & Tea
# 2     Sports Wear             Bars         Computers   Department Stores
# 3     Electronics     Coffee & Tea     Mobile Phones     Sports Medicine
# 4       Computers          Turkish   Medical Centers             Turkish
# 5    Sports Clubs      Dance Clubs       Electronics                Bars
# 6   Mobile Phones   Middle Eastern  Health & Medical             Seafood
# 7           Bikes        Wine Bars           Jewelry          Gift Shops
# 8         Fashion           Indian           Seafood   Men's Hair Salons
# 9           Parks  Persian/Iranian  Permanent Makeup  Convenience Stores
#
# [10 rows x 50 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-2c464c145eb5> in <module>()
# ----> 1 lsi.ascarray()
#
# AttributeError: 'LsiModel' object has no attribute 'ascarray'
